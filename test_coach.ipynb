# %%
import os
from src.climbing_coach import ClimbingCoach, CoachMode
from src.climber_profile import ClimberProfile
API_KEY = "REMOVED_API_KEY"
coach = ClimbingCoach.from_mistral(
    api_key=API_KEY,
    db_path="database/climbing.db",          # optional — omit if no DB yet
    profile_path="database/franck.json",
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 from src.climbing_coach import ClimbingCoach, CoachMode
#       3 from src.climber_profile import ClimberProfile
#       4 API_KEY = "REMOVED_API_KEY"
#       5 coach = ClimbingCoach.from_mistral(
#
# File c:\Users\Franc\OneDrive\Documents\GitHub\test_arkose\src\climbing_coach.py:43
#      39 from typing import Optional
#      41 from openai import OpenAI
# ---> 43 from climber_profile import ClimberProfile, Injury
#      44 from sboulder_collector import ROUTE_TYPES_BY_ID, ROUTE_TYPE_LEAF_IDS
#      46 log = logging.getLogger("climbing_coach")
#
# ModuleNotFoundError: No module named 'climber_profile'

# %%
# opening = coach.start_session(CoachMode.ONBOARDING)
# print(f"Coach : {opening}\n")

# while True:
#     user_input = input("Toi : ").strip()
#     if not user_input:
#         continue
#     if user_input.lower() == "fin":
#         break
#     print(f"\nCoach : {coach.chat(user_input)}\n")

# %%
# profile = coach.extract_profile_from_history()
# print(profile.to_llm_context())
# coach.save_profile()   # saves to franck.json

# %%
coach.profile = ClimberProfile.load("franck.json")
opening = coach.start_session(CoachMode.COACHING)
print(f"Coach : {opening}\n")

while True:
    user_input = input("Toi : ").strip()
    if not user_input:
        continue
    if user_input.lower() == "fin":
        break
    print(f"\nCoach : {coach.chat(user_input)}\n")
